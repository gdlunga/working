# %%
npoints<-550
size<-30

# %% [markdown]
# White noise example

# %%
w = rnorm(npoints,0,1)
plot.ts(w)
# Out:
# plot without title

# %% [markdown]
# adding moving average...

# %%
plot.ts(w)
v=filter(w,sides=1,filter=rep(1/size,size))
lines(v,col='yellow')
# Out:
# plot without title
