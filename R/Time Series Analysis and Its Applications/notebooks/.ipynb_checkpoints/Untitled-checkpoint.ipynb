# %%
npoints<-550
size<-30

# %% [markdown]
# White noise example

# %%
w = rnorm(npoints,0,1)
plot.ts(w)
# Out:
# plot without title

# %% [markdown]
# moving average on white noise

# %%
v=filter(w,sides=1,filter=rep(1/size,size))
lines(v,col='yellow')
# Out:
# Error in plot.xy(xy.coords(x, y), type = type, ...): plot.new has not been called yet
