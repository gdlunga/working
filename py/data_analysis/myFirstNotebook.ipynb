# %% [markdown]
# # Esempi tratti da: Python for Data Analysis

# %% [markdown]
# ## Esempio 1

# %%
import json
from pandas import DataFrame, Series
from collections import defaultdict

def get_counts(sequence):
    counts=defaultdict(int)
    for x in sequence:
        counts[x]  +=1
    return counts

#path = "Z:\pydata-book-master\ch02\usagov_bitly_data2012-03-16-1331923249.txt"
path     = "/Users/giovanni/Google Drive/Programming/python/Python for Data Analysis/ch02/"
filename = "usagov_bitly_data2012-03-16-1331923249.txt"
records  = [json.loads(line) for line in open(path + filename)]

# extract time zones
time_zones = [rec['tz'] for rec in records if 'tz' in rec]
counts     = get_counts(time_zones)

for t in time_zones:
    print t
    
print counts['America/New_York']
# Out:
# America/New_York
# America/Denver
# America/New_York
# America/Sao_Paulo
# America/New_York
# America/New_York
# Europe/Warsaw
#
#
#
# America/Los_Angeles
# America/New_York
# America/New_York
# America/New_York
# Asia/Hong_Kong
# Asia/Hong_Kong
# America/New_York
# America/Denver
# Europe/Rome
# Africa/Ceuta
# America/New_York
# America/New_York
# America/New_York
# Europe/Madrid
# Asia/Kuala_Lumpur
# Asia/Nicosia
# America/Sao_Paulo
#
#
# Europe/London
# America/New_York
# Pacific/Honolulu
# America/Chicago
#
#
# Pacific/Honolulu
#
# America/New_York
# America/New_York
# America/New_York
# America/Chicago
# Europe/Rome
# America/New_York
# America/New_York
# America/Los_Angeles
#
#
# America/New_York
# America/New_York
# Europe/Malta
# America/New_York
# America/New_York
#
# America/Los_Angeles
# America/Sao_Paulo
#
# Asia/Hong_Kong
# Asia/Hong_Kong
# Pacific/Honolulu
# Pacific/Honolulu
# Pacific/Honolulu
# America/New_York
# Europe/London
# America/New_York
#
# Europe/Lisbon
# ...

# %% [markdown]
# ## Esempio 2

# %%
import pandas as pd

#data_path       = 'D:/workspace/pyDataAnalysis_working/pydata-book-master/ch02/movielens'
data_path       = "/Users/giovanni/Google Drive/Programming/python/Python for Data Analysis/ch02/movielens"
user_file       = data_path + '/users.dat'
ratings_file    = data_path + '/ratings.dat'
movies_file     = data_path + '/movies.dat'

unames  = ['user_id', 'gender', 'age', 'occupation', 'zip']
users   = pd.read_table(user_file,      sep = '::', header=None, names=unames, engine='python')

rnames  = ['user_id', 'movie_id', 'rating', 'timestamp']
ratings = pd.read_table(ratings_file,   sep = '::', header=None, names=rnames, engine='python')

mnames  = ['movie_id', 'title', 'genres']
movies  = pd.read_table(movies_file,     sep = '::', header=None, names=mnames, engine='python')

print users[:5]
# Out:
#    user_id gender  age  occupation    zip
# 0        1      F    1          10  48067
# 1        2      M   56          16  70072
# 2        3      M   25          15  55117
# 3        4      M   45           7  02460
# 4        5      M   25          20  55455

# %% [markdown]
# #### Esempio di utilizzo di latex

# %% [markdown]
# Questo è un'integrale : ${1 \over \sqrt{2\pi}}\int\limits_{-\infty}^{+\infty} e^{-{1 \over 2}x^2} = 1$
#
# Scriviamo l'equazione di Schroedinger:
#
# $$i \hbar {\partial \over \partial t} \Psi (x,t ) = {\hat H} \Psi(x,t) = -{\hbar^2 \over 2m}\nabla^2 \Psi(x,t)$$

# %% [markdown]
# ## Esempi notebook

# %%
import numpy as np
import pandas as pd

path     = "/Users/giovanni/Google Drive/Programming/python/Python for Data Analysis/"

tips     = pd.read_csv(path + 'ch08/tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# %matplotlib inline

import matplotlib
import matplotlib.pyplot as plt

img = plt.imread(path + 'ch03/stinkbug.png')
plt.figure(figsize=(3,3))
plt.imshow(img)
