# %%
from PIL import Image
from pytesser import *
 
image_file = '../img/20150911_191808.jpg'
im = Image.open(image_file)
text = image_to_string(im)
text = image_file_to_string(image_file)
text = image_file_to_string(image_file, graceful_errors=True)
print "=====output=======\n"
print text
# Out:
# =====output=======
#
#
#
# UNICQQP FIRENZE 800. COOPERATIVA
# SIRADA DEL PARADISO, 1/3/5
#
# (3()()F3
#
# SIENA Tel.
# P.1VA 00407780485
#
# 0577f334899
#
# TESSERA N. 0210wwwrw*115
# In1210 Salvatempo~w01532617
#
# 2
#
# POMODORO OBL.ROSSO G
#
# X
#
# 1.70
#
# SPINACI COOP BS 04
# ODORI MISTI IT vs
# BRES. MANZO CIPRES
# CECE VALFR.
# TONNO RIO MARE AGa
# TONNO RIO MARE PUT
# TONNO PICCANTE
# ZUCCH.CANNA coop
#
# BARATTOL PANNA GOTTA
#
# FETTE BISC.MB X32
# NUTELLA VASETTO 450
#
# CAR.FORNO CUKI 6MT+2
#
# 3
# SHOPPER
#
# X
#
# BIO
#
# 0.05
#
# PESCHE COTOGNE AA
# ZUCCHINE FIORE SF
# CIPOLLE ROSSE SF
# Fine Salvatempo
# ARTICOLI
#
# ~...~...H.~w~~——J~-
#
# xx L0 '5: I E:
#
# 1F (3
#
# SPESA IN
# B§§IQA,.
#
# 1'
#
# W
#
# 20
#
# ..,. ... w. .
#
# :7 u." A
#
# KAI” . A
#
# 0300031”:
#
# 4 .A’A“‘,“"‘-A#IMI:A _ A_ H:
#
# mmmmmoooo
#
# QLDNNOOQD
#
#
#
# c: (51(510101
#
# ~4COk‘h4 (ﬂea
# x:cav*
